# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
#googleのリポジトリ一覧ページのURL
url = "https://github.com/orgs/google/repositories"

# %%
#内容を取得
response = requests.get(url)
html_content = response.text

# %%
#アクセスできたか確認
print(f"ステータスコード: {response.status_code}")
# Out:
# ステータスコード: 200

# %%
#BeautifulSoupで解析
soup = BeautifulSoup(html_content, "html.parser")

# %%
repos = soup.find_all("li", class_="public source") 
print(f"見つかった数: {len(repos)}")
for repo in repos:
    #データの抽出
    
    # リポジトリ名を取得
    name = repo.find("h3").text.strip()
    
    # 言語を取得
    language_tag = repo.find("span", itemprop="programmingLanguage")
    if language_tag:
        language = language_tag.text.strip()
    else:
        language = "None" # 言語指定がない場合
        
    # スター数を取得
    star_tag = repo.find("a", href=lambda x: x and x.endswith("/stargazers"))
    star = star_tag.text.strip() if star_tag else "0"

    print(f"名前: {name}, 言語: {language}, スター: {star}")
# Out:
# 見つかった数: 0
